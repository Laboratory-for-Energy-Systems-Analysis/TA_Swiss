# %%
from premise import *
import bw2data
from datapackage import Package
bw2data.projects.set_current("ecoinvent-3.11-cutoff")

from premise import PathwaysDataPackage
clear_inventory_cache()
sps = Package("../datapackage.json")

STEM_scenarios = [
    "SPS1",
    "SPS1_AP1_MD",
    "SPS1_AP2_MD",
    "SPS1_AP3_MD",
    "SPS1_AP4_MD",
    "SPS1_AP5_MD",
    "SPS2",
    "SPS2_AP1_MD",
    "SPS2_AP2_MD",
    "SPS2_AP3_MD",
    "SPS2_AP4_MD",
    "SPS2_AP5_MD",
    "SPS4",
    "SPS4_AP1_MD",
    "SPS4_AP2_MD",
    "SPS4_AP3_MD",
    "SPS4_AP4_MD",
    "SPS4_AP5_MD"
]

scenarios=[
    {"model": "remind", "pathway": "SSP2-PkBudg1000", "external scenarios": [{"scenario": stem_scenario, "data": sps}]}
    for stem_scenario in STEM_scenarios
]

for scenario in scenarios:
    name=f"{scenario['model']}-{scenario['pathway']}-stem-{scenario['external scenarios'][0]['scenario']}"
    print(name)
    ndb = PathwaysDataPackage(
        scenarios=[
            scenario,
        ],
        source_db="ecoinvent-3.11-cutoff",
        source_version="3.11",
        key="tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=",
        use_absolute_efficiency=True,
        biosphere_name="biosphere3"
    )
    
    ndb.create_datapackage(
        name=name,
        contributors=[
            {"name": "Romain",
            "email": "r_s at me.com",}
        ],
    )
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/premise/lib/python3.12/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.3.0)/charset_normalizer (3.4.6) doesn't match a supported version!
#   warnings.warn(
# 10:19:06-0700 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# Inventory cache cleared!
# remind-SSP2-PkBudg1000-stem-SPS1
# premise v.(2, 3, 9)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your Brightway project:                                   |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# Cannot find cached inventories. Will create them now for next time...
# Importing default inventories...
#
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-Carma-CCS.xlsx
# Extracted 1 worksheets in 0.25 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.5 -> 3.6
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-co-firing-power-plants.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.5 -> 3.6
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-combined-heat-power-plant-CCS.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.5 -> 3.6
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-carbon-capture.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-biogas.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-waste-CHP.xlsx
# Extracted 4 worksheets in 0.12 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-carbon-fiber.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-lithium.xlsx
# Extracted 7 worksheets in 0.02 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-cobalt.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-batteries-NMC955-LTO.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------------------------+
# |              Name              |       Reference product        | Location |              File             |
# +--------------------------------+--------------------------------+----------+-------------------------------+
# | market for battery management  | battery management system, for |   GLO    | lci-batteries-NMC955-LTO.xlsx |
# | battery management system prod | battery management system, for |   GLO    | lci-batteries-NMC955-LTO.xlsx |
# +--------------------------------+--------------------------------+----------+-------------------------------+
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-batteries-LiS.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-batteries-LiO2.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-batteries-vanadium.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-----------------------------+
# |              Name              |       Reference product        | Location |             File            |
# +--------------------------------+--------------------------------+----------+-----------------------------+
# | market for styrene butadiene r | styrene butadiene rubber (SBR) |   RER    | lci-batteries-vanadium.xlsx |
# +--------------------------------+--------------------------------+----------+-----------------------------+
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-batteries-vanadium-redox-flow.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-batteries-organic-and-hybrid-redox-flow.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Could not find a biosphere flow for ('Heat, waste', 'air', 'lower stratosphere + upper troposphere', 'megajoule') in lci-batteries-organic-and-hybrid-redox-flow.xlsx. Flow ignored.
# Could not find a biosphere flow for ('Heat, waste', 'air', 'lower stratosphere + upper troposphere', 'megajoule') in lci-batteries-organic-and-hybrid-redox-flow.xlsx. Flow ignored.
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-batteries-SIB.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-battery-capacity.xlsx
# Extracted 2 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-home-batteries.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-heat-pump-high-temp.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-PV.xlsx
# Extracted 2 worksheets in 0.95 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------+
# |              Name              |       Reference product        | Location |     File    |
# +--------------------------------+--------------------------------+----------+-------------+
# | 1,1-difluoroethane production  |       1,1-difluoroethane       |    US    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | fluorspar production, 97% puri |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, front sid |   RER    | lci-PV.xlsx |
# |   multi-Si wafer production    |         multi-Si wafer         |   RER    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic flat-roof install | photovoltaic flat-roof install |    CH    | lci-PV.xlsx |
# | photovoltaic flat-roof install | photovoltaic flat-roof install |    CH    | lci-PV.xlsx |
# | photovoltaic laminate producti | photovoltaic laminate, multi-S |   RER    | lci-PV.xlsx |
# | photovoltaic laminate producti | photovoltaic laminate, single- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic panel factory con |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# | photovoltaic panel production, | photovoltaic panel, multi-Si w |   RER    | lci-PV.xlsx |
# | photovoltaic panel production, | photovoltaic panel, single-Si  |   RER    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaics, electric instal | photovoltaics, electric instal |    CH    | lci-PV.xlsx |
# |  polyvinylfluoride production  |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# | polyvinylfluoride production,  | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# | polyvinylfluoride, film produc |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# | silicon production, multi-Si,  |   silicon, multi-Si, casted    |   RER    | lci-PV.xlsx |
# | silicon production, single cry | silicon, single crystal, Czoch |   RER    | lci-PV.xlsx |
# | silicon production, solar grad |      silicon, solar grade      |   RER    | lci-PV.xlsx |
# | single-Si wafer production, ph | single-Si wafer, photovoltaic  |   RER    | lci-PV.xlsx |
# |   vinyl fluoride production    |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |   wafer factory construction   |         wafer factory          |    DE    | lci-PV.xlsx |
# +--------------------------------+--------------------------------+----------+-------------+
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-PGM.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-electrolysis.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-thermochemical-water-splitting.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-pyrolysis.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-methanol-from-electrolysis.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-methanol-from-cement-plant.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-coal-gasification.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | hydrogen production, coal gasi | hydrogen, gaseous, low pressur |   RoW    | lci-hydrogen-coal-gasification |
# | methanol production, from coal |            methanol            |   RoW    | lci-hydrogen-coal-gasification |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-coal-gasification_CCS.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-methanol-from-coal.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-methanol-from-coal-with-CCS.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-distribution.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-smr-atr-biogas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-smr-atr-natgas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | hydrogen production, steam met | hydrogen, gaseous, low pressur |   RER    | lci-hydrogen-smr-atr-natgas.xl |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-wood-gasification.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-oil.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-turbine.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-syngas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-methanol-from-wood.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | methanol production facility,  | methanol production facility,  |   RER    | lci-synfuels-from-methanol-fro |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-ammonia.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-syngas-from-coal.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-biofuels.xlsx
# Extracted 5 worksheets in 0.09 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-electrolysis.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-natural-gas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-wood-gasification.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-wood-gasification-with-CCS.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-coal-gasification.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-coal-gasification-with-CCS.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-geothermal.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-BIGCC.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-nuclear_EPR.xlsx
# Extracted 1 worksheets in 0.05 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-nuclear_SMR.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# WARNING: missing classification for electricity production, nuclear, Small Modular Reactor (SMR) | electricity, high voltage
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-wave_energy.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-fuel_cell.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-concentrating-solar-power.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-heating.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-methanol-heating.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-electric-heating.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-germanium.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Could not find a biosphere flow for ('Sodium I', 'natural resource', 'in ground', 'kilogram') in lci-germanium.xlsx. Flow ignored.
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-rhenium.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-two_wheelers.xlsx
# Extracted 19 worksheets in 0.30 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-trucks.xlsx
# Extracted 1 worksheets in 0.08 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-buses.xlsx
# Extracted 1 worksheets in 0.11 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+----------------+
# |              Name              |       Reference product        | Location |      File      |
# +--------------------------------+--------------------------------+----------+----------------+
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-buses.xlsx |
# +--------------------------------+--------------------------------+----------+----------------+
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-pass_cars.xlsx
# Extracted 1 worksheets in 1.16 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +-----------------+-------------------+----------+--------------------+
# |       Name      | Reference product | Location |        File        |
# +-----------------+-------------------+----------+--------------------+
# | HDPE tank liner |  HDPE tank liner  |   RER    | lci-pass_cars.xlsx |
# +-----------------+-------------------+----------+--------------------+
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-rail-freight.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-PV-GaAs.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-PV-perovskite.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-biochar-spruce.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-ocean-liming.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/tagger/Documents/GitHub/premise/premise/data/additional_inventories/lci-coastal-enhanced-weathering.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# ...
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# No suppliers found for market for heavy fuel oil (SPS) in CH. No market created. This may cause linking issue.
# Processing scenarios for all sectors:  95%|▉| 19/20 [24:31<01:18, 78.9
# Importing /Users/tagger/Documents/GitHub/TA_Swiss/inventories/lci-sweet_sure.xlsx
# Extracted 1 worksheets in 0.05 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+---------------------+
# |              Name              |       Reference product        | Location |         File        |
# +--------------------------------+--------------------------------+----------+---------------------+
# |     charging station, 3kW      |     charging station, 3kW      |   GLO    | lci-sweet_sure.xlsx |
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-sweet_sure.xlsx |
# +--------------------------------+--------------------------------+----------+---------------------+
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# No suppliers found for market for heavy fuel oil (SPS) in CH. No market created. This may cause linking issue.
# Processing scenarios for all sectors: 100%|█| 20/20 [25:50<00:00, 77.5
# Done!
#
# Write new database(s) to matrix.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2005.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2010.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2015.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2020.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2025.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2030.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2035.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2040.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2045.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2050.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2055.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2060.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2065.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2070.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2075.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2080.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2085.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2090.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2095.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_AP5_MD/2100.
# Generate scenario report.
# Report saved under /Users/tagger/Documents/GitHub/TA_Swiss/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/tagger/Documents/GitHub/TA_Swiss/dev/export/change reports/.
# Missing classifications for 1 unique activities (TSV, also saved to /Users/tagger/Documents/GitHub/TA_Swiss/dev/pathways_temp/classifications/missing_classifications.tsv):
# name	reference product
# electricity production, nuclear, Small Modular Reactor (SMR)	electricity, high voltage
# Data package saved at /Users/tagger/Documents/GitHub/TA_Swiss/dev/remind-SSP2-PkBudg1000-stem-SPS4_AP5_MD.zip
