# %%
import numpy as np
from pathways import Pathways

# %%
from pathways.lcia import get_lcia_method_names

# %%
STEM_scenarios = {
    #"SPS1":"SPS1_bas0",
    #"SPS2":"SPS2_bas0",
    #"SPS3":"SPS3_bas0",
    #"SPS4":"SPS4_bas0",
    #"SPS1_FIN_Low":"SPS1_fin1",
    #"SPS1_FIN_Mid":"SPS1_fin2",
    #"SPS1_FIN_High":"SPS1_fin3",
    #"SPS2_FIN_Low":"SPS2_fin1",
    #"SPS2_FIN_Mid":"SPS2_fin2",
    #"SPS2_FIN_High":"SPS2_fin3",
    #"SPS3_FIN_Low":"SPS3_fin1",
    #"SPS3_FIN_Mid":"SPS3_fin2",
    #"SPS3_FIN_High":"SPS3_fin3",
    #"SPS4_FIN_Low":"SPS4_fin1",
    #"SPS4_FIN_Mid":"SPS4_fin2",
    #"SPS4_FIN_High":"SPS4_fin3",
    #"SPS1_SOC_Low":"SPS1_soc1",
    #"SPS1_SOC_Mid":"SPS1_soc2",
    #"SPS1_SOC_High":"SPS1_soc3",
    #"SPS2_SOC_Low":"SPS2_soc1",
    #"SPS2_SOC_Mid":"SPS2_soc2",
    #"SPS2_SOC_High":"SPS2_soc3",
    #"SPS3_SOC_Low":"SPS3_soc1",
    #"SPS3_SOC_Mid":"SPS3_soc2",
    #"SPS3_SOC_High":"SPS3_soc3",
    #"SPS4_SOC_Low":"SPS4_soc1",
    #"SPS4_SOC_Mid":"SPS4_soc2",
    #"SPS4_SOC_High":"SPS4_soc3",
    #"SPS1_NUC_Low":"SPS1_nuc1",
    "SPS1_NUC_Mid":"SPS1_nuc2",
    "SPS1_NUC_High":"SPS1_nuc3",
    "SPS2_NUC_Low":"SPS2_nuc1",
    "SPS2_NUC_Mid":"SPS2_nuc2",
    "SPS2_NUC_High":"SPS2_nuc3",
    "SPS3_NUC_Low":"SPS3_nuc1",
    "SPS3_NUC_Mid":"SPS3_nuc2",
    "SPS3_NUC_High":"SPS3_nuc3",
    "SPS4_NUC_Low":"SPS4_nuc1",
    "SPS4_NUC_Mid":"SPS4_nuc2",
    "SPS4_NUC_High":"SPS4_nuc3",
}

for STEM_scenario in STEM_scenarios.values():
    fp = f"remind-SSP2-PkBudg1000-stem-{STEM_scenario}.zip"

    p = Pathways(datapackage=fp, debug=False, ecoinvent_version="3.11")

    p.calculate(
        methods=[
            'EN15804+A2 - Core impact categories and indicators - climate change: total (EF v3.0 - IPCC 2013) - global warming potential (GWP100)',
            'EN15804+A2 - Core impact categories and indicators - material resources: metals/minerals - abiotic depletion potential (ADP): elements (ultimate reserves)',
            'Inventory results and indicators - resources - land occupation',
            'EN15804+A2 - Indicators describing resource use - net use of fresh water - FW',
            'ReCiPe 2016 v1.03, endpoint (H) - total: human health - human health',
            'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
        ],
        regions=["CH",],
        scenarios=p.scenarios.pathway.values.tolist(),
        variables=[v for v in p.scenarios.coords["variables"].values if v.startswith("EXT - 0 - FE")],
        years=[
            2020,
            2025,
            2030,
            2035,
            2040,
            2050
        ],
        multiprocessing=True,
        use_distributions=0,
        # subshares=True,
    )
    p.export_results(filename=fp.replace(".zip", "").replace("remind", "results_remind"))
    del p
# Out:
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS1_nuc2...
# ------ Calculating LCA results for 2020...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2035...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS1_nuc2.gzip
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS1_nuc3...
# ------ Calculating LCA results for 2020...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2035...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS1_nuc3.gzip
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS2_nuc1...
# ------ Calculating LCA results for 2020...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2035...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS2_nuc1.gzip
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS2_nuc2...
# ------ Calculating LCA results for 2020...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2035...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS2_nuc2.gzip
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS2_nuc3...
# ------ Calculating LCA results for 2020...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2035...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS2_nuc3.gzip
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS3_nuc1...
# ------ Calculating LCA results for 2020...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2035...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS3_nuc1.gzip
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS3_nuc2...
# ------ Calculating LCA results for 2020...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2035...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS3_nuc2.gzip
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS3_nuc3...
# ------ Calculating LCA results for 2020...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2035...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS3_nuc3.gzip
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS4_nuc1...
# ------ Calculating LCA results for 2020...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2035...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS4_nuc1.gzip
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS4_nuc2...
# ------ Calculating LCA results for 2020...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2035...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS4_nuc2.gzip
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS4_nuc3...
# ------ Calculating LCA results for 2020...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2035...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Missing classification: ['market for heavy fuel oil (SPS)', 'heavy fuel oil']
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Missing classification: ['market for light fuel oil (SPS)', 'light fuel oil']
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS4_nuc3.gzip

# %%
import pandas as pd
from premise.geomap import Geomap
from pivottablejs import pivot_ui
from IPython.display import HTML

# %%
STEM_scenarios = {
    "SPS1":"SPS1_bas0",
    "SPS2":"SPS2_bas0",
    "SPS3":"SPS3_bas0",
    "SPS4":"SPS4_bas0",
    "SPS1_FIN_Low":"SPS1_fin1",
    "SPS1_FIN_Mid":"SPS1_fin2",
    "SPS1_FIN_High":"SPS1_fin3",
    "SPS2_FIN_Low":"SPS2_fin1",
    "SPS2_FIN_Mid":"SPS2_fin2",
    "SPS2_FIN_High":"SPS2_fin3",
    "SPS3_FIN_Low":"SPS3_fin1",
    "SPS3_FIN_Mid":"SPS3_fin2",
    "SPS3_FIN_High":"SPS3_fin3",
    "SPS4_FIN_Low":"SPS4_fin1",
    "SPS4_FIN_Mid":"SPS4_fin2",
    "SPS4_FIN_High":"SPS4_fin3",
    "SPS1_SOC_Low":"SPS1_soc1",
    "SPS1_SOC_Mid":"SPS1_soc2",
    "SPS1_SOC_High":"SPS1_soc3",
    "SPS2_SOC_Low":"SPS2_soc1",
    "SPS2_SOC_Mid":"SPS2_soc2",
    "SPS2_SOC_High":"SPS2_soc3",
    "SPS3_SOC_Low":"SPS3_soc1",
    "SPS3_SOC_Mid":"SPS3_soc2",
    "SPS3_SOC_High":"SPS3_soc3",
    "SPS4_SOC_Low":"SPS4_soc1",
    "SPS4_SOC_Mid":"SPS4_soc2",
    "SPS4_SOC_High":"SPS4_soc3",
    "SPS1_NUC_Low":"SPS1_nuc1",
    "SPS1_NUC_Mid":"SPS1_nuc2",
    "SPS1_NUC_High":"SPS1_nuc3",
    "SPS2_NUC_Low":"SPS2_nuc1",
    "SPS2_NUC_Mid":"SPS2_nuc2",
    "SPS2_NUC_High":"SPS2_nuc3",
    "SPS3_NUC_Low":"SPS3_nuc1",
    "SPS3_NUC_Mid":"SPS3_nuc2",
    "SPS3_NUC_High":"SPS3_nuc3",
    "SPS4_NUC_Low":"SPS4_nuc1",
    "SPS4_NUC_Mid":"SPS4_nuc2",
    "SPS4_NUC_High":"SPS4_nuc3",
}


fps = [
    f"results_remind-SSP2-PkBudg1000-stem-{fp}.gzip"
    for fp in STEM_scenarios.values()
]
fps
# Out:
# ['results_remind-SSP2-PkBudg1000-stem-SPS1_bas0.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS2_bas0.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS3_bas0.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS4_bas0.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS1_fin1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS1_fin2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS1_fin3.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS2_fin1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS2_fin2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS2_fin3.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS3_fin1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS3_fin2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS3_fin3.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS4_fin1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS4_fin2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS4_fin3.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS1_soc1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS1_soc2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS1_soc3.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS2_soc1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS2_soc2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS2_soc3.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS3_soc1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS3_soc2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS3_soc3.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS4_soc1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS4_soc2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS4_soc3.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS1_nuc1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS1_nuc2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS1_nuc3.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS2_nuc1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS2_nuc2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS2_nuc3.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS3_nuc1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS3_nuc2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS3_nuc3.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS4_nuc1.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS4_nuc2.gzip',
#  'results_remind-SSP2-PkBudg1000-stem-SPS4_nuc3.gzip']

# %%
mapping = {
    
    "EXT - 0 - FE_bus_electricity": "transport",
    "EXT - 0 - FE_bus_gas": "transport",
    "EXT - 0 - FE_bus_hydrogen": "transport",
    "EXT - 0 - FE_cars_diesel": "transport",
    "EXT - 0 - FE_cars_electricity": "transport",
    "EXT - 0 - FE_cars_gas": "transport",
    "EXT - 0 - FE_cars_gasoline": "transport",
    "EXT - 0 - FE_cars_hydrogen": "transport",
    "EXT - 0 - FE_coach_diesel": "transport",
    "EXT - 0 - FE_coach_electricity": "transport",
    "EXT - 0 - FE_coach_gas": "transport",
    "EXT - 0 - FE_coach_hydrogen": "transport",
    "EXT - 0 - FE_heavy_duty_truck_diesel": "transport",
    "EXT - 0 - FE_heavy_duty_truck_electricity": "transport",
    "EXT - 0 - FE_heavy_duty_truck_gas": "transport",
    "EXT - 0 - FE_heavy_duty_truck_hydrogen": "transport",
    "EXT - 0 - FE_light_duty_truck_diesel": "transport",
    "EXT - 0 - FE_light_duty_truck_electricity": "transport",
    "EXT - 0 - FE_light_duty_truck_gas": "transport",
    "EXT - 0 - FE_light_duty_truck_gasoline": "transport",
    "EXT - 0 - FE_light_duty_truck_hydrogen": "transport",
    "EXT - 0 - FE_motorcycle_electric": "transport",
    "EXT - 0 - FE_motorcycle_gasoline": "transport",
    "EXT - 0 - FE_motorcycle_hydrogen": "transport",
    "EXT - 0 - FE_other_transport_diesel": "transport",
    "EXT - 0 - FE_other_transport_electric": "transport",
    "EXT - 0 - FE_other_transport_hydrogen": "transport",
    "EXT - 0 - FE_tram": "transport",
    "EXT - 0 - FE_trolleybus": "transport",

    "EXT - 0 - FE_industry_heat_CHP_fuel_cell": "industry",
    "EXT - 0 - FE_industry_heat_CHP_gas": "industry",
    "EXT - 0 - FE_industry_heat_CHP_gas_CCS": "industry",
    "EXT - 0 - FE_industry_heat_CHP_hydrogen": "industry",
    "EXT - 0 - FE_industry_heat_CHP_oil": "industry",
    "EXT - 0 - FE_industry_heat_CHP_waste_non_renew": "industry",
    "EXT - 0 - FE_industry_heat_CHP_waste_non_renew_CCS": "industry",
    "EXT - 0 - FE_industry_heat_CHP_wood": "industry",
    "EXT - 0 - FE_industry_heat_CHP_wood_CCS": "industry",
    "EXT - 0 - FE_industry_heat_DH": "industry",
    "EXT - 0 - FE_industry_process_FE_other_electric": "industry",
    "EXT - 0 - FE_industry_process_coal": "industry",
    "EXT - 0 - FE_industry_process_electric_boiler": "industry",
    "EXT - 0 - FE_industry_process_heat_pump": "industry",
    "EXT - 0 - FE_industry_process_hydrogen": "industry",
    "EXT - 0 - FE_industry_process_light_fuel_oil": "industry",
    "EXT - 0 - FE_industry_process_natural_gas": "industry",
    "EXT - 0 - FE_industry_process_pellet": "industry",
    "EXT - 0 - FE_industry_process_solar": "industry",
    "EXT - 0 - FE_industry_process_waste_non_renew": "industry",
    "EXT - 0 - FE_industry_process_wood": "industry",

    "EXT - 0 - FE_residential_FE_other_electric": "residential",
    "EXT - 0 - FE_residential_space_heating_CHP_gas": "residential",
    "EXT - 0 - FE_residential_space_heating_CHP_wood": "residential",
    "EXT - 0 - FE_residential_space_heating_DH": "residential",
    "EXT - 0 - FE_residential_space_heating_electric_boiler": "residential",
    "EXT - 0 - FE_residential_space_heating_gas": "residential",
    "EXT - 0 - FE_residential_space_heating_heat_pump": "residential",
    "EXT - 0 - FE_residential_space_heating_heat_pump_gas": "residential",
    "EXT - 0 - FE_residential_space_heating_light_fuel_oil": "residential",
    "EXT - 0 - FE_residential_space_heating_pellet": "residential",
    "EXT - 0 - FE_residential_space_heating_solar": "residential",
    "EXT - 0 - FE_residential_space_heating_wood": "residential",
    "EXT - 0 - FE_residential_water_heating_electric_boiler": "residential",
    "EXT - 0 - FE_residential_water_heating_gas": "residential",
    "EXT - 0 - FE_residential_water_heating_heat_pump": "residential",
    "EXT - 0 - FE_residential_water_heating_heat_pump_gas": "residential",
    "EXT - 0 - FE_residential_water_heating_light_fuel_oil": "residential",
    "EXT - 0 - FE_residential_water_heating_pellet": "residential",
    "EXT - 0 - FE_residential_water_heating_solar": "residential",
    "EXT - 0 - FE_residential_water_heating_wood": "residential",

    "EXT - 0 - FE_services_CHP_biogas": "services",
    "EXT - 0 - FE_services_CHP_fuel_cell": "services",
    "EXT - 0 - FE_services_CHP_gas": "services",
    "EXT - 0 - FE_services_CHP_hydrogen": "services",
    "EXT - 0 - FE_services_CHP_wood": "services",
    "EXT - 0 - FE_services_DH": "services",
    "EXT - 0 - FE_services_FE_other_electric": "services",
    "EXT - 0 - FE_services_electric_boiler": "services",
    "EXT - 0 - FE_services_heat_pump": "services",
    "EXT - 0 - FE_services_hydrogen": "services",
    "EXT - 0 - FE_services_light_fuel_oil": "services",
    "EXT - 0 - FE_services_natural_gas": "services",
    "EXT - 0 - FE_services_pellet": "services",
    "EXT - 0 - FE_services_solar": "services",
    "EXT - 0 - FE_services_wood": "services",
}

# %%
df_final = pd.DataFrame()

for fp in fps:
    df = pd.read_parquet(fp, engine='pyarrow')
    df = df[df["value"]!=0.0]
    df = df[~df["value"].isnull()]
    df=df.reset_index()

    print(df["scenario"])
    
    geo = Geomap("remind")
    EU = geo.iam_to_ecoinvent_location("EUR")
    EU.extend(geo.iam_to_ecoinvent_location("NEU"))
    EU.remove("CH")
    EU.extend(["EUR", "NEU"])

    df.loc[df["location"].isin(EU), "location"] = "EU wo CH"
    df.loc[~df["location"].isin(["CH", "EU wo CH"]), "location"] = "RoW"

    df["sector"] = df["variable"].map(mapping)

    df = df.groupby([
        'sector', 'variable', 'year', 'region', 'model', 'scenario', 'impact_category', 'location']).sum().reset_index()
    df = df[['sector', 'variable', 'year', 'region', 'model', 'scenario', 'impact_category', 'location', "value"]]

    df["impact_category"] = df["impact_category"].str.replace("RELICS - metals extraction - ", "")
    
    df["impact_category"] = df["impact_category"].str.replace('EN15804+A2 - Core impact categories and indicators - material resources: metals/minerals - abiotic depletion potential (ADP): elements (ultimate reserves)', "minerals depletion")
    df["impact_category"] = df["impact_category"].str.replace('EN15804+A2 - Indicators describing resource use - ', "")
    df["impact_category"] = df["impact_category"].str.replace(' - FW', "")
    df["impact_category"] = df["impact_category"].str.replace("Inventory results and indicators - resources - ", "")
    df["impact_category"] = df["impact_category"].str.replace("ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ", "")
    df["impact_category"] = df["impact_category"].str.replace("ReCiPe 2016 v1.03, endpoint (H) - total: human health - ", "")
    
    
    df["impact_category"] = df["impact_category"].str.replace('EN15804+A2 - Core impact categories and indicators - climate change: total (EF v3.0 - IPCC 2013) - global warming potential (GWP100)', "climate change")
    df["impact_category"] = df["impact_category"].str.replace("selected LCI results - resource - land occupation", "land occupation")
    df["impact_category"] = df["impact_category"].str.replace("EF v3.1 - material resources: metals/minerals - abiotic depletion potential (ADP): elements (ultimate reserves)", "natural resources (minerals and metals)")
    df["impact_category"] = df["impact_category"].str.replace("IPCC 2021 - climate change - GWP 100a, incl. H and bio CO2", "climate change")
    df["impact_category"] = df["impact_category"].str.replace("Cumulative Energy Demand (CED) - energy resources: renewable - energy content (HHV)", "renewable primary energy")
    df["impact_category"] = df["impact_category"].str.replace("Cumulative Energy Demand (CED) - energy resources: non-renewable - energy content (HHV)", "non-renewable primary energy")
    df["impact_category"] = df["impact_category"].str.replace("ReCiPe 2016 v1.03, endpoint (I) - total: ecosystem quality - ecosystem quality", "ecosystem impact")
    df["impact_category"] = df["impact_category"].str.replace("ReCiPe 2016 v1.03, endpoint (E) - total: human health - human health", "human health")
    df["impact_category"] = df["impact_category"].str.replace("Ecological Scarcity 2021 - total - UBP", "ecological scarcity")

    units = {
        "climate change": "kg CO2-eq.",
        "land occupation": "square meter-year",
        "natural resources (minerals and metals)": "kg Sb-eq.",
        "minerals depletion": "kg Sb-eq.",
        "use of net fresh water": "m3",
        "renewable primary energy": "MJ (HHV)",
        "non-renewable primary energy": "MJ (HHV)",
        "ecosystem impact": "species-year lost",
        "ecosystem quality": "species-year lost",
        "human health": "DALY",
        "ecological scarcity": "UBP pt"
    }
    df["unit"] = df["impact_category"].map(units)
    df.loc[df["unit"].isnull(), "unit"] = "kg"

    df_final = pd.concat([df_final, df])

    pivot_ui(df, outfile_path=f'pivottable_{fp.split("-")[-1]}.html')

    
    pivot = df.pivot_table(
        index=['sector', 'variable', 'region', 'model', 'scenario', 'impact_category', 'location', 'unit'], 
        columns='year', 
        values='value', 
        aggfunc='sum'
    ).reset_index()
    
    
    pivot.to_excel(f"{fp.replace('.gzip', '_indicators_')}.xlsx")
    
    print(fp)

pivot_ui(df_final, outfile_path=f'pivottable_all_scenarios.html')
df_final.to_excel("df_final.xlsx")
# Out:
# 0          SSP2-PkBudg1000 - SPS1_bas0
# 1          SSP2-PkBudg1000 - SPS1_bas0
# 2          SSP2-PkBudg1000 - SPS1_bas0
# 3          SSP2-PkBudg1000 - SPS1_bas0
# 4          SSP2-PkBudg1000 - SPS1_bas0
#                       ...
# 4186344    SSP2-PkBudg1000 - SPS1_bas0
# 4186345    SSP2-PkBudg1000 - SPS1_bas0
# 4186346    SSP2-PkBudg1000 - SPS1_bas0
# 4186347    SSP2-PkBudg1000 - SPS1_bas0
# 4186348    SSP2-PkBudg1000 - SPS1_bas0
# Name: scenario, Length: 4186349, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS1_bas0.gzip
# 0          SSP2-PkBudg1000 - SPS2_bas0
# 1          SSP2-PkBudg1000 - SPS2_bas0
# 2          SSP2-PkBudg1000 - SPS2_bas0
# 3          SSP2-PkBudg1000 - SPS2_bas0
# 4          SSP2-PkBudg1000 - SPS2_bas0
#                       ...
# 4404723    SSP2-PkBudg1000 - SPS2_bas0
# 4404724    SSP2-PkBudg1000 - SPS2_bas0
# 4404725    SSP2-PkBudg1000 - SPS2_bas0
# 4404726    SSP2-PkBudg1000 - SPS2_bas0
# 4404727    SSP2-PkBudg1000 - SPS2_bas0
# Name: scenario, Length: 4404728, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS2_bas0.gzip
# 0          SSP2-PkBudg1000 - SPS3_bas0
# 1          SSP2-PkBudg1000 - SPS3_bas0
# 2          SSP2-PkBudg1000 - SPS3_bas0
# 3          SSP2-PkBudg1000 - SPS3_bas0
# 4          SSP2-PkBudg1000 - SPS3_bas0
#                       ...
# 4202200    SSP2-PkBudg1000 - SPS3_bas0
# 4202201    SSP2-PkBudg1000 - SPS3_bas0
# 4202202    SSP2-PkBudg1000 - SPS3_bas0
# 4202203    SSP2-PkBudg1000 - SPS3_bas0
# 4202204    SSP2-PkBudg1000 - SPS3_bas0
# Name: scenario, Length: 4202205, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS3_bas0.gzip
# 0          SSP2-PkBudg1000 - SPS4_bas0
# 1          SSP2-PkBudg1000 - SPS4_bas0
# 2          SSP2-PkBudg1000 - SPS4_bas0
# 3          SSP2-PkBudg1000 - SPS4_bas0
# 4          SSP2-PkBudg1000 - SPS4_bas0
#                       ...
# 4147565    SSP2-PkBudg1000 - SPS4_bas0
# 4147566    SSP2-PkBudg1000 - SPS4_bas0
# 4147567    SSP2-PkBudg1000 - SPS4_bas0
# 4147568    SSP2-PkBudg1000 - SPS4_bas0
# 4147569    SSP2-PkBudg1000 - SPS4_bas0
# Name: scenario, Length: 4147570, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS4_bas0.gzip
# 0          SSP2-PkBudg1000 - SPS1_fin1
# 1          SSP2-PkBudg1000 - SPS1_fin1
# 2          SSP2-PkBudg1000 - SPS1_fin1
# 3          SSP2-PkBudg1000 - SPS1_fin1
# 4          SSP2-PkBudg1000 - SPS1_fin1
#                       ...
# 4304159    SSP2-PkBudg1000 - SPS1_fin1
# 4304160    SSP2-PkBudg1000 - SPS1_fin1
# 4304161    SSP2-PkBudg1000 - SPS1_fin1
# 4304162    SSP2-PkBudg1000 - SPS1_fin1
# 4304163    SSP2-PkBudg1000 - SPS1_fin1
# Name: scenario, Length: 4304164, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS1_fin1.gzip
# 0          SSP2-PkBudg1000 - SPS1_fin2
# 1          SSP2-PkBudg1000 - SPS1_fin2
# 2          SSP2-PkBudg1000 - SPS1_fin2
# 3          SSP2-PkBudg1000 - SPS1_fin2
# 4          SSP2-PkBudg1000 - SPS1_fin2
#                       ...
# 4373204    SSP2-PkBudg1000 - SPS1_fin2
# 4373205    SSP2-PkBudg1000 - SPS1_fin2
# 4373206    SSP2-PkBudg1000 - SPS1_fin2
# 4373207    SSP2-PkBudg1000 - SPS1_fin2
# 4373208    SSP2-PkBudg1000 - SPS1_fin2
# Name: scenario, Length: 4373209, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS1_fin2.gzip
# 0          SSP2-PkBudg1000 - SPS1_fin3
# 1          SSP2-PkBudg1000 - SPS1_fin3
# 2          SSP2-PkBudg1000 - SPS1_fin3
# 3          SSP2-PkBudg1000 - SPS1_fin3
# 4          SSP2-PkBudg1000 - SPS1_fin3
#                       ...
# 4363486    SSP2-PkBudg1000 - SPS1_fin3
# 4363487    SSP2-PkBudg1000 - SPS1_fin3
# 4363488    SSP2-PkBudg1000 - SPS1_fin3
# 4363489    SSP2-PkBudg1000 - SPS1_fin3
# 4363490    SSP2-PkBudg1000 - SPS1_fin3
# Name: scenario, Length: 4363491, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS1_fin3.gzip
# 0          SSP2-PkBudg1000 - SPS2_fin1
# 1          SSP2-PkBudg1000 - SPS2_fin1
# 2          SSP2-PkBudg1000 - SPS2_fin1
# 3          SSP2-PkBudg1000 - SPS2_fin1
# 4          SSP2-PkBudg1000 - SPS2_fin1
#                       ...
# 4451774    SSP2-PkBudg1000 - SPS2_fin1
# 4451775    SSP2-PkBudg1000 - SPS2_fin1
# 4451776    SSP2-PkBudg1000 - SPS2_fin1
# 4451777    SSP2-PkBudg1000 - SPS2_fin1
# 4451778    SSP2-PkBudg1000 - SPS2_fin1
# Name: scenario, Length: 4451779, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS2_fin1.gzip
# 0          SSP2-PkBudg1000 - SPS2_fin2
# 1          SSP2-PkBudg1000 - SPS2_fin2
# 2          SSP2-PkBudg1000 - SPS2_fin2
# 3          SSP2-PkBudg1000 - SPS2_fin2
# 4          SSP2-PkBudg1000 - SPS2_fin2
#                       ...
# 4461598    SSP2-PkBudg1000 - SPS2_fin2
# 4461599    SSP2-PkBudg1000 - SPS2_fin2
# 4461600    SSP2-PkBudg1000 - SPS2_fin2
# 4461601    SSP2-PkBudg1000 - SPS2_fin2
# 4461602    SSP2-PkBudg1000 - SPS2_fin2
# Name: scenario, Length: 4461603, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS2_fin2.gzip
# 0          SSP2-PkBudg1000 - SPS2_fin3
# 1          SSP2-PkBudg1000 - SPS2_fin3
# 2          SSP2-PkBudg1000 - SPS2_fin3
# 3          SSP2-PkBudg1000 - SPS2_fin3
# 4          SSP2-PkBudg1000 - SPS2_fin3
#                       ...
# 4442001    SSP2-PkBudg1000 - SPS2_fin3
# 4442002    SSP2-PkBudg1000 - SPS2_fin3
# 4442003    SSP2-PkBudg1000 - SPS2_fin3
# 4442004    SSP2-PkBudg1000 - SPS2_fin3
# 4442005    SSP2-PkBudg1000 - SPS2_fin3
# Name: scenario, Length: 4442006, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS2_fin3.gzip
# 0          SSP2-PkBudg1000 - SPS3_fin1
# 1          SSP2-PkBudg1000 - SPS3_fin1
# 2          SSP2-PkBudg1000 - SPS3_fin1
# 3          SSP2-PkBudg1000 - SPS3_fin1
# 4          SSP2-PkBudg1000 - SPS3_fin1
#                       ...
# 4232938    SSP2-PkBudg1000 - SPS3_fin1
# 4232939    SSP2-PkBudg1000 - SPS3_fin1
# 4232940    SSP2-PkBudg1000 - SPS3_fin1
# 4232941    SSP2-PkBudg1000 - SPS3_fin1
# 4232942    SSP2-PkBudg1000 - SPS3_fin1
# Name: scenario, Length: 4232943, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS3_fin1.gzip
# 0          SSP2-PkBudg1000 - SPS3_fin2
# 1          SSP2-PkBudg1000 - SPS3_fin2
# 2          SSP2-PkBudg1000 - SPS3_fin2
# 3          SSP2-PkBudg1000 - SPS3_fin2
# 4          SSP2-PkBudg1000 - SPS3_fin2
#                       ...
# 4232971    SSP2-PkBudg1000 - SPS3_fin2
# 4232972    SSP2-PkBudg1000 - SPS3_fin2
# 4232973    SSP2-PkBudg1000 - SPS3_fin2
# 4232974    SSP2-PkBudg1000 - SPS3_fin2
# 4232975    SSP2-PkBudg1000 - SPS3_fin2
# Name: scenario, Length: 4232976, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS3_fin2.gzip
# 0          SSP2-PkBudg1000 - SPS3_fin3
# 1          SSP2-PkBudg1000 - SPS3_fin3
# 2          SSP2-PkBudg1000 - SPS3_fin3
# 3          SSP2-PkBudg1000 - SPS3_fin3
# 4          SSP2-PkBudg1000 - SPS3_fin3
#                       ...
# 4242775    SSP2-PkBudg1000 - SPS3_fin3
# 4242776    SSP2-PkBudg1000 - SPS3_fin3
# 4242777    SSP2-PkBudg1000 - SPS3_fin3
# 4242778    SSP2-PkBudg1000 - SPS3_fin3
# 4242779    SSP2-PkBudg1000 - SPS3_fin3
# Name: scenario, Length: 4242780, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS3_fin3.gzip
# 0          SSP2-PkBudg1000 - SPS4_fin1
# 1          SSP2-PkBudg1000 - SPS4_fin1
# 2          SSP2-PkBudg1000 - SPS4_fin1
# 3          SSP2-PkBudg1000 - SPS4_fin1
# 4          SSP2-PkBudg1000 - SPS4_fin1
#                       ...
# 4235784    SSP2-PkBudg1000 - SPS4_fin1
# 4235785    SSP2-PkBudg1000 - SPS4_fin1
# 4235786    SSP2-PkBudg1000 - SPS4_fin1
# 4235787    SSP2-PkBudg1000 - SPS4_fin1
# 4235788    SSP2-PkBudg1000 - SPS4_fin1
# Name: scenario, Length: 4235789, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS4_fin1.gzip
# 0          SSP2-PkBudg1000 - SPS4_fin2
# 1          SSP2-PkBudg1000 - SPS4_fin2
# 2          SSP2-PkBudg1000 - SPS4_fin2
# 3          SSP2-PkBudg1000 - SPS4_fin2
# 4          SSP2-PkBudg1000 - SPS4_fin2
#                       ...
# 4245757    SSP2-PkBudg1000 - SPS4_fin2
# 4245758    SSP2-PkBudg1000 - SPS4_fin2
# 4245759    SSP2-PkBudg1000 - SPS4_fin2
# 4245760    SSP2-PkBudg1000 - SPS4_fin2
# 4245761    SSP2-PkBudg1000 - SPS4_fin2
# Name: scenario, Length: 4245762, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS4_fin2.gzip
# 0          SSP2-PkBudg1000 - SPS4_fin3
# 1          SSP2-PkBudg1000 - SPS4_fin3
# 2          SSP2-PkBudg1000 - SPS4_fin3
# 3          SSP2-PkBudg1000 - SPS4_fin3
# 4          SSP2-PkBudg1000 - SPS4_fin3
#                       ...
# 4236711    SSP2-PkBudg1000 - SPS4_fin3
# 4236712    SSP2-PkBudg1000 - SPS4_fin3
# 4236713    SSP2-PkBudg1000 - SPS4_fin3
# 4236714    SSP2-PkBudg1000 - SPS4_fin3
# 4236715    SSP2-PkBudg1000 - SPS4_fin3
# Name: scenario, Length: 4236716, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS4_fin3.gzip
# 0          SSP2-PkBudg1000 - SPS1_soc1
# 1          SSP2-PkBudg1000 - SPS1_soc1
# 2          SSP2-PkBudg1000 - SPS1_soc1
# 3          SSP2-PkBudg1000 - SPS1_soc1
# 4          SSP2-PkBudg1000 - SPS1_soc1
#                       ...
# 4304330    SSP2-PkBudg1000 - SPS1_soc1
# 4304331    SSP2-PkBudg1000 - SPS1_soc1
# 4304332    SSP2-PkBudg1000 - SPS1_soc1
# 4304333    SSP2-PkBudg1000 - SPS1_soc1
# 4304334    SSP2-PkBudg1000 - SPS1_soc1
# Name: scenario, Length: 4304335, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS1_soc1.gzip
# 0          SSP2-PkBudg1000 - SPS1_soc2
# 1          SSP2-PkBudg1000 - SPS1_soc2
# 2          SSP2-PkBudg1000 - SPS1_soc2
# 3          SSP2-PkBudg1000 - SPS1_soc2
# 4          SSP2-PkBudg1000 - SPS1_soc2
#                       ...
# 4255340    SSP2-PkBudg1000 - SPS1_soc2
# 4255341    SSP2-PkBudg1000 - SPS1_soc2
# 4255342    SSP2-PkBudg1000 - SPS1_soc2
# 4255343    SSP2-PkBudg1000 - SPS1_soc2
# 4255344    SSP2-PkBudg1000 - SPS1_soc2
# Name: scenario, Length: 4255345, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS1_soc2.gzip
# 0          SSP2-PkBudg1000 - SPS1_soc3
# 1          SSP2-PkBudg1000 - SPS1_soc3
# 2          SSP2-PkBudg1000 - SPS1_soc3
# 3          SSP2-PkBudg1000 - SPS1_soc3
# 4          SSP2-PkBudg1000 - SPS1_soc3
#                       ...
# 4265197    SSP2-PkBudg1000 - SPS1_soc3
# 4265198    SSP2-PkBudg1000 - SPS1_soc3
# 4265199    SSP2-PkBudg1000 - SPS1_soc3
# 4265200    SSP2-PkBudg1000 - SPS1_soc3
# 4265201    SSP2-PkBudg1000 - SPS1_soc3
# Name: scenario, Length: 4265202, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS1_soc3.gzip
# 0          SSP2-PkBudg1000 - SPS2_soc1
# 1          SSP2-PkBudg1000 - SPS2_soc1
# 2          SSP2-PkBudg1000 - SPS2_soc1
# 3          SSP2-PkBudg1000 - SPS2_soc1
# 4          SSP2-PkBudg1000 - SPS2_soc1
#                       ...
# 4432117    SSP2-PkBudg1000 - SPS2_soc1
# 4432118    SSP2-PkBudg1000 - SPS2_soc1
# 4432119    SSP2-PkBudg1000 - SPS2_soc1
# 4432120    SSP2-PkBudg1000 - SPS2_soc1
# 4432121    SSP2-PkBudg1000 - SPS2_soc1
# Name: scenario, Length: 4432122, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS2_soc1.gzip
# 0          SSP2-PkBudg1000 - SPS2_soc2
# 1          SSP2-PkBudg1000 - SPS2_soc2
# 2          SSP2-PkBudg1000 - SPS2_soc2
# 3          SSP2-PkBudg1000 - SPS2_soc2
# 4          SSP2-PkBudg1000 - SPS2_soc2
#                       ...
# 4432084    SSP2-PkBudg1000 - SPS2_soc2
# 4432085    SSP2-PkBudg1000 - SPS2_soc2
# 4432086    SSP2-PkBudg1000 - SPS2_soc2
# 4432087    SSP2-PkBudg1000 - SPS2_soc2
# 4432088    SSP2-PkBudg1000 - SPS2_soc2
# Name: scenario, Length: 4432089, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS2_soc2.gzip
# 0          SSP2-PkBudg1000 - SPS2_soc3
# 1          SSP2-PkBudg1000 - SPS2_soc3
# 2          SSP2-PkBudg1000 - SPS2_soc3
# 3          SSP2-PkBudg1000 - SPS2_soc3
# 4          SSP2-PkBudg1000 - SPS2_soc3
#                       ...
# 4481458    SSP2-PkBudg1000 - SPS2_soc3
# 4481459    SSP2-PkBudg1000 - SPS2_soc3
# 4481460    SSP2-PkBudg1000 - SPS2_soc3
# 4481461    SSP2-PkBudg1000 - SPS2_soc3
# 4481462    SSP2-PkBudg1000 - SPS2_soc3
# Name: scenario, Length: 4481463, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS2_soc3.gzip
# 0          SSP2-PkBudg1000 - SPS3_soc1
# 1          SSP2-PkBudg1000 - SPS3_soc1
# 2          SSP2-PkBudg1000 - SPS3_soc1
# 3          SSP2-PkBudg1000 - SPS3_soc1
# 4          SSP2-PkBudg1000 - SPS3_soc1
#                       ...
# 4252639    SSP2-PkBudg1000 - SPS3_soc1
# 4252640    SSP2-PkBudg1000 - SPS3_soc1
# 4252641    SSP2-PkBudg1000 - SPS3_soc1
# 4252642    SSP2-PkBudg1000 - SPS3_soc1
# 4252643    SSP2-PkBudg1000 - SPS3_soc1
# Name: scenario, Length: 4252644, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS3_soc1.gzip
# 0          SSP2-PkBudg1000 - SPS3_soc2
# 1          SSP2-PkBudg1000 - SPS3_soc2
# 2          SSP2-PkBudg1000 - SPS3_soc2
# 3          SSP2-PkBudg1000 - SPS3_soc2
# 4          SSP2-PkBudg1000 - SPS3_soc2
#                       ...
# 4252609    SSP2-PkBudg1000 - SPS3_soc2
# 4252610    SSP2-PkBudg1000 - SPS3_soc2
# 4252611    SSP2-PkBudg1000 - SPS3_soc2
# 4252612    SSP2-PkBudg1000 - SPS3_soc2
# 4252613    SSP2-PkBudg1000 - SPS3_soc2
# Name: scenario, Length: 4252614, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS3_soc2.gzip
# 0          SSP2-PkBudg1000 - SPS3_soc3
# 1          SSP2-PkBudg1000 - SPS3_soc3
# 2          SSP2-PkBudg1000 - SPS3_soc3
# 3          SSP2-PkBudg1000 - SPS3_soc3
# 4          SSP2-PkBudg1000 - SPS3_soc3
#                       ...
# 4252071    SSP2-PkBudg1000 - SPS3_soc3
# 4252072    SSP2-PkBudg1000 - SPS3_soc3
# 4252073    SSP2-PkBudg1000 - SPS3_soc3
# 4252074    SSP2-PkBudg1000 - SPS3_soc3
# 4252075    SSP2-PkBudg1000 - SPS3_soc3
# Name: scenario, Length: 4252076, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS3_soc3.gzip
# 0          SSP2-PkBudg1000 - SPS4_soc1
# 1          SSP2-PkBudg1000 - SPS4_soc1
# 2          SSP2-PkBudg1000 - SPS4_soc1
# 3          SSP2-PkBudg1000 - SPS4_soc1
# 4          SSP2-PkBudg1000 - SPS4_soc1
#                       ...
# 4267872    SSP2-PkBudg1000 - SPS4_soc1
# 4267873    SSP2-PkBudg1000 - SPS4_soc1
# 4267874    SSP2-PkBudg1000 - SPS4_soc1
# 4267875    SSP2-PkBudg1000 - SPS4_soc1
# 4267876    SSP2-PkBudg1000 - SPS4_soc1
# Name: scenario, Length: 4267877, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS4_soc1.gzip
# 0          SSP2-PkBudg1000 - SPS4_soc2
# 1          SSP2-PkBudg1000 - SPS4_soc2
# 2          SSP2-PkBudg1000 - SPS4_soc2
# 3          SSP2-PkBudg1000 - SPS4_soc2
# 4          SSP2-PkBudg1000 - SPS4_soc2
#                       ...
# 4267755    SSP2-PkBudg1000 - SPS4_soc2
# 4267756    SSP2-PkBudg1000 - SPS4_soc2
# 4267757    SSP2-PkBudg1000 - SPS4_soc2
# 4267758    SSP2-PkBudg1000 - SPS4_soc2
# 4267759    SSP2-PkBudg1000 - SPS4_soc2
# Name: scenario, Length: 4267760, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS4_soc2.gzip
# 0          SSP2-PkBudg1000 - SPS4_soc3
# 1          SSP2-PkBudg1000 - SPS4_soc3
# 2          SSP2-PkBudg1000 - SPS4_soc3
# 3          SSP2-PkBudg1000 - SPS4_soc3
# 4          SSP2-PkBudg1000 - SPS4_soc3
#                       ...
# 4268854    SSP2-PkBudg1000 - SPS4_soc3
# 4268855    SSP2-PkBudg1000 - SPS4_soc3
# 4268856    SSP2-PkBudg1000 - SPS4_soc3
# 4268857    SSP2-PkBudg1000 - SPS4_soc3
# 4268858    SSP2-PkBudg1000 - SPS4_soc3
# Name: scenario, Length: 4268859, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS4_soc3.gzip
# 0          SSP2-PkBudg1000 - SPS1_nuc1
# 1          SSP2-PkBudg1000 - SPS1_nuc1
# 2          SSP2-PkBudg1000 - SPS1_nuc1
# 3          SSP2-PkBudg1000 - SPS1_nuc1
# 4          SSP2-PkBudg1000 - SPS1_nuc1
#                       ...
# 4395027    SSP2-PkBudg1000 - SPS1_nuc1
# 4395028    SSP2-PkBudg1000 - SPS1_nuc1
# 4395029    SSP2-PkBudg1000 - SPS1_nuc1
# 4395030    SSP2-PkBudg1000 - SPS1_nuc1
# 4395031    SSP2-PkBudg1000 - SPS1_nuc1
# Name: scenario, Length: 4395032, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS1_nuc1.gzip
# 0          SSP2-PkBudg1000 - SPS1_nuc2
# 1          SSP2-PkBudg1000 - SPS1_nuc2
# 2          SSP2-PkBudg1000 - SPS1_nuc2
# 3          SSP2-PkBudg1000 - SPS1_nuc2
# 4          SSP2-PkBudg1000 - SPS1_nuc2
#                       ...
# 4284511    SSP2-PkBudg1000 - SPS1_nuc2
# 4284512    SSP2-PkBudg1000 - SPS1_nuc2
# 4284513    SSP2-PkBudg1000 - SPS1_nuc2
# 4284514    SSP2-PkBudg1000 - SPS1_nuc2
# 4284515    SSP2-PkBudg1000 - SPS1_nuc2
# Name: scenario, Length: 4284516, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS1_nuc2.gzip
# 0          SSP2-PkBudg1000 - SPS1_nuc3
# 1          SSP2-PkBudg1000 - SPS1_nuc3
# 2          SSP2-PkBudg1000 - SPS1_nuc3
# 3          SSP2-PkBudg1000 - SPS1_nuc3
# 4          SSP2-PkBudg1000 - SPS1_nuc3
#                       ...
# 4296807    SSP2-PkBudg1000 - SPS1_nuc3
# 4296808    SSP2-PkBudg1000 - SPS1_nuc3
# 4296809    SSP2-PkBudg1000 - SPS1_nuc3
# 4296810    SSP2-PkBudg1000 - SPS1_nuc3
# 4296811    SSP2-PkBudg1000 - SPS1_nuc3
# Name: scenario, Length: 4296812, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS1_nuc3.gzip
# 0          SSP2-PkBudg1000 - SPS2_nuc1
# 1          SSP2-PkBudg1000 - SPS2_nuc1
# 2          SSP2-PkBudg1000 - SPS2_nuc1
# 3          SSP2-PkBudg1000 - SPS2_nuc1
# 4          SSP2-PkBudg1000 - SPS2_nuc1
#                       ...
# 4332225    SSP2-PkBudg1000 - SPS2_nuc1
# 4332226    SSP2-PkBudg1000 - SPS2_nuc1
# 4332227    SSP2-PkBudg1000 - SPS2_nuc1
# 4332228    SSP2-PkBudg1000 - SPS2_nuc1
# 4332229    SSP2-PkBudg1000 - SPS2_nuc1
# Name: scenario, Length: 4332230, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS2_nuc1.gzip
# 0          SSP2-PkBudg1000 - SPS2_nuc2
# 1          SSP2-PkBudg1000 - SPS2_nuc2
# 2          SSP2-PkBudg1000 - SPS2_nuc2
# 3          SSP2-PkBudg1000 - SPS2_nuc2
# 4          SSP2-PkBudg1000 - SPS2_nuc2
#                       ...
# 4401187    SSP2-PkBudg1000 - SPS2_nuc2
# 4401188    SSP2-PkBudg1000 - SPS2_nuc2
# 4401189    SSP2-PkBudg1000 - SPS2_nuc2
# 4401190    SSP2-PkBudg1000 - SPS2_nuc2
# 4401191    SSP2-PkBudg1000 - SPS2_nuc2
# Name: scenario, Length: 4401192, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS2_nuc2.gzip
# 0          SSP2-PkBudg1000 - SPS2_nuc3
# 1          SSP2-PkBudg1000 - SPS2_nuc3
# 2          SSP2-PkBudg1000 - SPS2_nuc3
# 3          SSP2-PkBudg1000 - SPS2_nuc3
# 4          SSP2-PkBudg1000 - SPS2_nuc3
#                       ...
# 4362283    SSP2-PkBudg1000 - SPS2_nuc3
# 4362284    SSP2-PkBudg1000 - SPS2_nuc3
# 4362285    SSP2-PkBudg1000 - SPS2_nuc3
# 4362286    SSP2-PkBudg1000 - SPS2_nuc3
# 4362287    SSP2-PkBudg1000 - SPS2_nuc3
# Name: scenario, Length: 4362288, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS2_nuc3.gzip
# 0          SSP2-PkBudg1000 - SPS3_nuc1
# 1          SSP2-PkBudg1000 - SPS3_nuc1
# 2          SSP2-PkBudg1000 - SPS3_nuc1
# 3          SSP2-PkBudg1000 - SPS3_nuc1
# 4          SSP2-PkBudg1000 - SPS3_nuc1
#                       ...
# 4222959    SSP2-PkBudg1000 - SPS3_nuc1
# 4222960    SSP2-PkBudg1000 - SPS3_nuc1
# 4222961    SSP2-PkBudg1000 - SPS3_nuc1
# 4222962    SSP2-PkBudg1000 - SPS3_nuc1
# 4222963    SSP2-PkBudg1000 - SPS3_nuc1
# Name: scenario, Length: 4222964, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS3_nuc1.gzip
# 0          SSP2-PkBudg1000 - SPS3_nuc2
# 1          SSP2-PkBudg1000 - SPS3_nuc2
# 2          SSP2-PkBudg1000 - SPS3_nuc2
# 3          SSP2-PkBudg1000 - SPS3_nuc2
# 4          SSP2-PkBudg1000 - SPS3_nuc2
#                       ...
# 4232804    SSP2-PkBudg1000 - SPS3_nuc2
# 4232805    SSP2-PkBudg1000 - SPS3_nuc2
# 4232806    SSP2-PkBudg1000 - SPS3_nuc2
# 4232807    SSP2-PkBudg1000 - SPS3_nuc2
# 4232808    SSP2-PkBudg1000 - SPS3_nuc2
# Name: scenario, Length: 4232809, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS3_nuc2.gzip
# 0          SSP2-PkBudg1000 - SPS3_nuc3
# 1          SSP2-PkBudg1000 - SPS3_nuc3
# 2          SSP2-PkBudg1000 - SPS3_nuc3
# 3          SSP2-PkBudg1000 - SPS3_nuc3
# 4          SSP2-PkBudg1000 - SPS3_nuc3
#                       ...
# 4222927    SSP2-PkBudg1000 - SPS3_nuc3
# 4222928    SSP2-PkBudg1000 - SPS3_nuc3
# 4222929    SSP2-PkBudg1000 - SPS3_nuc3
# 4222930    SSP2-PkBudg1000 - SPS3_nuc3
# 4222931    SSP2-PkBudg1000 - SPS3_nuc3
# Name: scenario, Length: 4222932, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS3_nuc3.gzip
# 0          SSP2-PkBudg1000 - SPS4_nuc1
# 1          SSP2-PkBudg1000 - SPS4_nuc1
# 2          SSP2-PkBudg1000 - SPS4_nuc1
# 3          SSP2-PkBudg1000 - SPS4_nuc1
# 4          SSP2-PkBudg1000 - SPS4_nuc1
#                       ...
# 4245724    SSP2-PkBudg1000 - SPS4_nuc1
# 4245725    SSP2-PkBudg1000 - SPS4_nuc1
# 4245726    SSP2-PkBudg1000 - SPS4_nuc1
# 4245727    SSP2-PkBudg1000 - SPS4_nuc1
# 4245728    SSP2-PkBudg1000 - SPS4_nuc1
# Name: scenario, Length: 4245729, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS4_nuc1.gzip
# 0          SSP2-PkBudg1000 - SPS4_nuc2
# 1          SSP2-PkBudg1000 - SPS4_nuc2
# 2          SSP2-PkBudg1000 - SPS4_nuc2
# 3          SSP2-PkBudg1000 - SPS4_nuc2
# 4          SSP2-PkBudg1000 - SPS4_nuc2
#                       ...
# 4245737    SSP2-PkBudg1000 - SPS4_nuc2
# 4245738    SSP2-PkBudg1000 - SPS4_nuc2
# 4245739    SSP2-PkBudg1000 - SPS4_nuc2
# 4245740    SSP2-PkBudg1000 - SPS4_nuc2
# 4245741    SSP2-PkBudg1000 - SPS4_nuc2
# Name: scenario, Length: 4245742, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS4_nuc2.gzip
# 0          SSP2-PkBudg1000 - SPS4_nuc3
# 1          SSP2-PkBudg1000 - SPS4_nuc3
# 2          SSP2-PkBudg1000 - SPS4_nuc3
# 3          SSP2-PkBudg1000 - SPS4_nuc3
# 4          SSP2-PkBudg1000 - SPS4_nuc3
#                       ...
# 4225717    SSP2-PkBudg1000 - SPS4_nuc3
# 4225718    SSP2-PkBudg1000 - SPS4_nuc3
# 4225719    SSP2-PkBudg1000 - SPS4_nuc3
# 4225720    SSP2-PkBudg1000 - SPS4_nuc3
# 4225721    SSP2-PkBudg1000 - SPS4_nuc3
# Name: scenario, Length: 4225722, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS4_nuc3.gzip
