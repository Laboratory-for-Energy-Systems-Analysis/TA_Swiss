# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap
import matplotlib.patches as patches
from matplotlib.font_manager import FontProperties

# %% [markdown]
# ## Import data

# %%
file_path = "stem_results.xlsx"

# %%
sps1_emissions = "SPS1 - emissions"
sps1_sources = "SPS1 - e generation"
sps4_emissions = "SPS4 - emissions"
sps4_sources = "SPS4 - e generation"

# %%
df_sps1_emissions = pd.read_excel(file_path, sheet_name=sps1_emissions)
df_sps1_sources = pd.read_excel(file_path, sheet_name=sps1_sources)
df_sps4_emissions = pd.read_excel(file_path, sheet_name=sps4_emissions)
df_sps4_sources = pd.read_excel(file_path, sheet_name=sps4_sources)

# %%
df_sps1_sources
# Out:
#      SPS Region                   Sector    unit        2020        2022  \
# 0   SPS1     CH                     Coal  PJ/yr.    3.660000    3.560737
# 1   SPS1     CH     Oil (fossil liquids)  PJ/yr.  305.537717  277.625167
# 2   SPS1     CH  Oil (synthetic liquids)  PJ/yr.    6.913297    7.421807
# 3   SPS1     CH             Gas (fossil)  PJ/yr.  116.925568  106.720000
# 4   SPS1     CH          Gas (synthetic)  PJ/yr.    0.000000    0.516500
# 5   SPS1     CH                  Nuclear  PJ/yr.  250.948170  253.300110
# 6   SPS1     CH                 Hydrogen  PJ/yr.    0.000000    0.000000
# 7   SPS1     CH                     Wood  PJ/yr.   44.770000   47.260901
# 8   SPS1     CH    Waste (non renewable)  PJ/yr.   35.611720   35.882383
# 9   SPS1     CH        Waste (renewable)  PJ/yr.   33.781043   33.781043
# 10  SPS1     CH                   Manure  PJ/yr.    3.798079    9.825592
# 11  SPS1     CH                    Hydro  PJ/yr.  149.430480  125.603999
# 12  SPS1     CH                    Solar  PJ/yr.   12.556445   16.523357
# 13  SPS1     CH                     Wind  PJ/yr.    0.524000    0.550800
# 14  SPS1     CH             Ambient heat  PJ/yr.   18.873012   21.891427
# 15  SPS1     CH               Geothermal  PJ/yr.    0.000000    0.000000
#
#           2025        2030        2040        2050
# 0     3.237455    0.000365    0.000000    0.000000
# 1   234.743482  139.307082   57.565217    0.000000
# 2     6.900671    5.961934    9.882039   26.112295
# 3    97.479622  107.673761   91.902475   54.898202
# 4     0.899662    1.838399    1.729539    0.000000
# 5   176.997547  189.382509   98.945499    0.000000
# 6     0.000000    0.000000    0.472193    1.425065
# 7    47.260901   47.260901   47.260901   63.755653
# 8    35.762048   35.039995   35.159449   35.603173
# 9    33.781043   33.781043   33.781043   33.781043
# 10    9.825592   12.066648   12.338459   18.000002
# 11  141.266673  150.312739  151.187702  151.986870
# 12   23.859714   30.899791   46.180755  102.869316
# 13    1.935373    2.752368    7.739825   15.480000
# 14   39.052360   59.413646   80.797868   84.855949
# 15    0.000000    0.000000    0.000000    0.000000

# %% [markdown]
# ## Apply cut off for "Other"

# %%
def apply_cutoff(df, cut_off):
    # Create a new DataFrame to store the categorized data
    df_categorized = df.copy()

    # Initialize an "Other" row if it doesn't exist
    if "Other" not in df_categorized["Sector"].values:
        other_row = pd.DataFrame({
            "SPS": [df["SPS"].iloc[0]],
            "Region": [df["Region"].iloc[0]],
            "Sector": ["Other"],
            "unit": [df["unit"].iloc[0]]
        })
        for col in df.columns[4:]:
            other_row[col] = 0
        df_categorized = pd.concat([df_categorized, other_row], ignore_index=True)

    # Loop over each year column to categorize variables
    for year in df.columns[4:]:
        total = df[year].sum()
        percentages = df[year].abs() / total

        # Identify variables that fall under the "Other" category
        other_sum = 0
        for i, percentage in percentages.items():
            if percentage < cut_off and df.at[i, year] >= 0:
                other_sum += df.at[i, year]
                df_categorized.at[i, year] = 0

        # # Debugging information
        # print(f"Year: {year}")
        # print(f"Total: {total}")
        # print(f"Percentages:\n{percentages}")
        # print(f"Other sum for year {year}: {other_sum}")

        # Update the "Other" row
        df_categorized.loc[df_categorized["Sector"] == "Other", year] += other_sum

    return df_categorized

# %%
cut_off = 0.05  # 5%

# %%
df_sps1_emissions_cutoff = apply_cutoff(df_sps1_emissions, cut_off)
df_sps1_sources_cutoff = apply_cutoff(df_sps1_sources, cut_off)
df_sps4_emissions_cutoff = apply_cutoff(df_sps4_emissions, cut_off)
df_sps4_sources_cutoff = apply_cutoff(df_sps4_sources, cut_off)

# %%
df_sps1_sources_cutoff
# Out:
#      SPS Region                   Sector    unit        2020        2022  \
# 0   SPS1     CH                     Coal  PJ/yr.    0.000000    0.000000
# 1   SPS1     CH     Oil (fossil liquids)  PJ/yr.  305.537717  277.625167
# 2   SPS1     CH  Oil (synthetic liquids)  PJ/yr.    0.000000    0.000000
# 3   SPS1     CH             Gas (fossil)  PJ/yr.  116.925568  106.720000
# 4   SPS1     CH          Gas (synthetic)  PJ/yr.    0.000000    0.000000
# 5   SPS1     CH                  Nuclear  PJ/yr.  250.948170  253.300110
# 6   SPS1     CH                 Hydrogen  PJ/yr.    0.000000    0.000000
# 7   SPS1     CH                     Wood  PJ/yr.    0.000000   47.260901
# 8   SPS1     CH    Waste (non renewable)  PJ/yr.    0.000000    0.000000
# 9   SPS1     CH        Waste (renewable)  PJ/yr.    0.000000    0.000000
# 10  SPS1     CH                   Manure  PJ/yr.    0.000000    0.000000
# 11  SPS1     CH                    Hydro  PJ/yr.  149.430480  125.603999
# 12  SPS1     CH                    Solar  PJ/yr.    0.000000    0.000000
# 13  SPS1     CH                     Wind  PJ/yr.    0.000000    0.000000
# 14  SPS1     CH             Ambient heat  PJ/yr.    0.000000    0.000000
# 15  SPS1     CH               Geothermal  PJ/yr.    0.000000    0.000000
# 16  SPS1     CH                    Other  PJ/yr.  160.487596  129.953644
#
#           2025        2030        2040        2050
# 0     0.000000    0.000000    0.000000    0.000000
# 1   234.743482  139.307082   57.565217    0.000000
# 2     0.000000    0.000000    0.000000    0.000000
# 3    97.479622  107.673761   91.902475   54.898202
# 4     0.000000    0.000000    0.000000    0.000000
# 5   176.997547  189.382509   98.945499    0.000000
# 6     0.000000    0.000000    0.000000    0.000000
# 7    47.260901   47.260901   47.260901   63.755653
# 8     0.000000    0.000000   35.159449   35.603173
# 9     0.000000    0.000000   33.781043   33.781043
# 10    0.000000    0.000000    0.000000    0.000000
# 11  141.266673  150.312739  151.187702  151.986870
# 12    0.000000    0.000000   46.180755  102.869316
# 13    0.000000    0.000000    0.000000    0.000000
# 14    0.000000   59.413646   80.797868   84.855949
# 15    0.000000    0.000000    0.000000    0.000000
# 16  155.253917  122.340542   32.162055   61.017362

# %%
# Remove rows where all values from 2020 to 2050 are zero
df_sps1_emissions_cutoff = df_sps1_emissions_cutoff[(df_sps1_emissions_cutoff.iloc[:, 4:] != 0).any(axis=1)]
df_sps1_sources_cutoff = df_sps1_sources_cutoff[(df_sps1_sources_cutoff.iloc[:, 4:] != 0).any(axis=1)]
df_sps4_emissions_cutoff = df_sps4_emissions_cutoff[(df_sps4_emissions_cutoff.iloc[:, 4:] != 0).any(axis=1)]
df_sps4_sources_cutoff = df_sps4_sources_cutoff[(df_sps4_sources_cutoff.iloc[:, 4:] != 0).any(axis=1)]

# %%
df_sps1_sources_cutoff
# Out:
#      SPS Region                 Sector    unit        2020        2022  \
# 1   SPS1     CH   Oil (fossil liquids)  PJ/yr.  305.537717  277.625167
# 3   SPS1     CH           Gas (fossil)  PJ/yr.  116.925568  106.720000
# 5   SPS1     CH                Nuclear  PJ/yr.  250.948170  253.300110
# 7   SPS1     CH                   Wood  PJ/yr.    0.000000   47.260901
# 8   SPS1     CH  Waste (non renewable)  PJ/yr.    0.000000    0.000000
# 9   SPS1     CH      Waste (renewable)  PJ/yr.    0.000000    0.000000
# 11  SPS1     CH                  Hydro  PJ/yr.  149.430480  125.603999
# 12  SPS1     CH                  Solar  PJ/yr.    0.000000    0.000000
# 14  SPS1     CH           Ambient heat  PJ/yr.    0.000000    0.000000
# 16  SPS1     CH                  Other  PJ/yr.  160.487596  129.953644
#
#           2025        2030        2040        2050
# 1   234.743482  139.307082   57.565217    0.000000
# 3    97.479622  107.673761   91.902475   54.898202
# 5   176.997547  189.382509   98.945499    0.000000
# 7    47.260901   47.260901   47.260901   63.755653
# 8     0.000000    0.000000   35.159449   35.603173
# 9     0.000000    0.000000   33.781043   33.781043
# 11  141.266673  150.312739  151.187702  151.986870
# 12    0.000000    0.000000   46.180755  102.869316
# 14    0.000000   59.413646   80.797868   84.855949
# 16  155.253917  122.340542   32.162055   61.017362

# %%
df_sps1_emissions_melted = df_sps1_emissions_cutoff.melt(
    id_vars=["SPS", "Region", "Sector", "unit"], 
    var_name="Year", 
    value_name="Value"
)
df_sps1_sources_melted = df_sps1_sources_cutoff.melt(
    id_vars=["SPS", "Region", "Sector", "unit"], 
    var_name="Year", 
    value_name="Value"
)

df_sps4_emissions_melted = df_sps4_emissions_cutoff.melt(
    id_vars=["SPS", "Region", "Sector", "unit"], 
    var_name="Year", 
    value_name="Value"
)
df_sps4_sources_melted = df_sps4_sources_cutoff.melt(
    id_vars=["SPS", "Region", "Sector", "unit"], 
    var_name="Year", 
    value_name="Value"
)

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Selecting the palette

# %%
sector_colors_sources = {
    "Oil (fossil liquids)": "midnightblue",
    "Gas (fossil)": "slateblue",
    "Nuclear": "forestgreen",
    "Wood": "darkgoldenrod",
    "Waste (non renewable)": "darkorange",
    "Waste (renewable)": "saddlebrown",
    "Hydro": "lightblue",
    "Solar": "gold",
    "Ambient heat": "lightsalmon",
    "Other": "dimgray"
}

sector_colors_emissions = {
    "Industry": "slateblue",
    "Other": "darkorange",
    "Power generation": "saddlebrown",
    "Residential": "lightsalmon",
    "Services": "lightblue",
    "Synthetic fuel production": "saddlebrown",
    "Transport": "midnightblue"
}

# # Create a consistent color map
# sectors = list(sector_colors.keys())
# colors = [sector_colors[sector] for sector in sectors]
# custom_colormap = ListedColormap(colors)

# %% [markdown]
# ## Plotting

# %%
# Set default font size for all plot elements
plt.rcParams.update({'font.size': 22, 'font.family': 'Verdana'})

# %%
def plot_with_consistent_colors(df, ax, title, xlim, sector_colors):
    sectors = df.columns
    color_map = [sector_colors[sector] for sector in sectors]
    df.plot(kind='barh', stacked=True, ax=ax, color=color_map, zorder=3)
    ax.set_title(title, fontsize=28, pad=30)
    # ax.set_xlabel(x_label, fontsize=26, labelpad=20)
    ax.set_xlim(xlim)
    ax.grid(True, zorder=0)
    for bar in ax.patches:
        bar.set_edgecolor('black')
        bar.set_linewidth(0.7)

# %%
# Pivot the data to aggregate values per year and sector
df_sources_pivot_sps1 = df_sps1_sources_melted.pivot(index='Year', columns='Sector', values='Value').fillna(0)
df_emissions_pivot_sps1 = df_sps1_emissions_melted.pivot(index='Year', columns='Sector', values='Value').fillna(0)
df_sources_pivot_sps4 = df_sps4_sources_melted.pivot(index='Year', columns='Sector', values='Value').fillna(0)
df_emissions_pivot_sps4 = df_sps4_emissions_melted.pivot(index='Year', columns='Sector', values='Value').fillna(0)

# Set up the figure and axes
fig, axs = plt.subplots(nrows=2, ncols=2, sharey='row', figsize=(30, 20), gridspec_kw={'wspace': 0.085, 'hspace': 0.5})

# Plot the SPS1 data
plot_with_consistent_colors(df_sources_pivot_sps4, axs[0, 0], 'Primary energy consumption [PJ/yr]', (1000, 0), sector_colors_sources)
axs[0, 0].invert_yaxis()
axs[0, 0].set_ylabel('')

plot_with_consistent_colors(df_emissions_pivot_sps4, axs[0, 1], 'Direct CO2 emissions [Mt CO2/yr]', (-2.5, 35), sector_colors_emissions)
axs[0, 1].invert_yaxis()
axs[0, 1].set_ylabel('')

axs[0, 0].legend().remove()  # Remove legend for the upper left plot
axs[0, 1].legend().remove()  # Remove legend for the upper right plot

# Plot the SPS4 data
plot_with_consistent_colors(df_sources_pivot_sps1, axs[1, 0], 'Primary energy consumption [PJ/yr]', (1000, 0), sector_colors_sources)
axs[1, 0].invert_yaxis()
axs[1, 0].set_ylabel('')

plot_with_consistent_colors(df_emissions_pivot_sps1, axs[1, 1], 'Direct CO2 emissions [Mt CO2/yr]', (-2.5, 35), sector_colors_emissions)
axs[1, 1].invert_yaxis()
axs[1, 1].set_ylabel('')

# Add legends under the lower plots
axs[1, 0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fontsize=24, ncol=2)
axs[1, 1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fontsize=24, ncol=2)

# Adjust y-ticks to be centered between the plots
axs[0, 0].yaxis.set_ticks_position('right')
axs[0, 0].yaxis.set_label_position('right')
axs[0, 1].yaxis.set_ticks_position('left')
axs[1, 0].yaxis.set_ticks_position('right')
axs[1, 0].yaxis.set_label_position('right')
axs[1, 1].yaxis.set_ticks_position('left')


# Ensure y-ticks are not bold
for ax in axs.flat:
    for label in ax.get_yticklabels():
        # label.set_fontsize(14)
        label.set_weight('normal')


# Add titles to the scenarios
fig.text(0.5, 0.97, 'Baseline scenario - Current trend and policies', ha='center', va='center', fontsize=28, weight='bold')
fig.text(0.5, 0.52, 'Net zero scenario - Focus on sustainability', ha='center', va='center', fontsize=28, weight='bold')

# Adjust layout and show the plot
# plt.tight_layout()
plt.subplots_adjust(top=0.90, bottom=0.15)
plt.show()

# %%
plt.savefig('scenario_results.png', dpi=300, bbox_inches='tight')

# %%
# # Pivot the data to aggregate values per year and sector
# df_sources_pivot_sps1 = df_sps1_sources_melted.pivot(index='Year', columns='Sector', values='Value').fillna(0)
# df_emissions_pivot_sps1 = df_sps1_emissions_melted.pivot(index='Year', columns='Sector', values='Value').fillna(0)
# df_sources_pivot_sps4 = df_sps4_sources_melted.pivot(index='Year', columns='Sector', values='Value').fillna(0)
# df_emissions_pivot_sps4 = df_sps4_emissions_melted.pivot(index='Year', columns='Sector', values='Value').fillna(0)

# # Set up the figure and axes
# fig, axs = plt.subplots(nrows=2, ncols=2, sharey='row', figsize=(30, 20), gridspec_kw={'wspace': 0.085, 'hspace': 0.4})

# # Plot the SPS1 data
# df_sources_pivot_sps4.plot(kind='barh', stacked=True, ax=axs[0, 0], colormap=custom_colormap, zorder=3)
# axs[0, 0].set_title('Primary energy consumption [PJ/year]', fontsize=28, pad=30)
# # axs[0, 0].set_xlabel('PJ/yr', fontsize=26, labelpad=20)
# axs[0, 0].set_ylabel('')
# axs[0, 0].invert_xaxis()
# axs[0, 0].invert_yaxis()
# axs[0, 0].set_xlim(1000, 0)
# axs[0, 0].grid(True, zorder=0)
# axs[0, 0].legend().remove()

# df_emissions_pivot_sps4.plot(kind='barh', stacked=True, ax=axs[0, 1], colormap=custom_colormap, zorder=3)
# axs[0, 1].set_title('Direct CO2 emissions [Mt CO2/yr]', fontsize=28, pad=30)
# # axs[0, 1].set_xlabel('Mt CO2/yr', fontsize=26, labelpad=20)
# axs[0, 1].set_ylabel('')
# axs[0, 1].invert_yaxis()
# axs[0, 1].set_xlim(-2.5, 35)
# axs[0, 1].grid(True, zorder=0)
# axs[0, 1].legend().remove()

# # Plot the SPS4 data
# df_sources_pivot_sps1.plot(kind='barh', stacked=True, ax=axs[1, 0], colormap=custom_colormap, zorder=3)
# axs[1, 0].set_title('Primary energy consumption [PJ/year]', fontsize=28, pad=30)
# # axs[1, 0].set_xlabel('PJ/yr', fontsize=26, labelpad=20)
# axs[1, 0].set_ylabel('')
# axs[1, 0].invert_xaxis()
# axs[1, 0].invert_yaxis()
# axs[1, 0].set_xlim(1000, 0)
# axs[1, 0].grid(True, zorder=0)

# df_emissions_pivot_sps1.plot(kind='barh', stacked=True, ax=axs[1, 1], colormap=custom_colormap, zorder=3)
# axs[1, 1].set_title('Direct CO2 emissions [Mt CO2/yr]', fontsize=28, pad=30)
# # axs[1, 1].set_xlabel('Mt CO2/yr', fontsize=26, labelpad=20)
# axs[1, 1].set_ylabel('')
# axs[1, 1].invert_yaxis()
# axs[1, 1].set_xlim(-2.5, 35)
# axs[1, 1].grid(True, zorder=0)

# # Add legends under the plots
# # axs[0, 0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fontsize=24, ncol=2)
# # axs[0, 1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fontsize=24, ncol=2)
# axs[1, 0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fontsize=24, ncol=2)
# axs[1, 1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fontsize=24, ncol=2)

# # Adjust y-ticks to be centered between the plots
# axs[0, 0].yaxis.set_ticks_position('right')
# axs[0, 0].yaxis.set_label_position('right')
# axs[0, 1].yaxis.set_ticks_position('left')
# axs[1, 0].yaxis.set_ticks_position('right')
# axs[1, 0].yaxis.set_label_position('right')
# axs[1, 1].yaxis.set_ticks_position('left')

# # Add borders to each sub-bar
# for ax in axs.flat:
#     for bar in ax.patches:
#         bar.set_edgecolor('gray')
#         bar.set_linewidth(0.7)

# # Add titles to the whole figure
# fig.text(0.5, 1, 'Baseline scenario - Current trend and policies', ha='center', va='center', fontsize=28, weight='bold')
# fig.text(0.5, 0.54, 'Net zero scenario - Focus on sustainability', ha='center', va='center', fontsize=28, weight='bold')

# # Adjust layout and show the plot
# # plt.tight_layout()
# plt.subplots_adjust(top=0.93, bottom=0.15)
# plt.show()
